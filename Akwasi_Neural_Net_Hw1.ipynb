# %%
#Question 1.
import numpy as np

a = []   #create empty list to hold all results
for num in np.arange(2000, 3200):
    if num%7 == 0 and num%5 != 0:
        a.append(num) #add number divisble by 7 and not 5 to a
print(a)    #print a
# Out:
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199]

# %%
#Question 2.
def fibo():
    n = int(input("Please enter the number of finonacci numbers desired: "))
    fb_list = []        #create empty list to hold all results
    a,b = 0,1
    if n < 0:
        n = int(input("Enter positive integer: ")) #Ensure positive
    while n >= 0 and len(fb_list) <= n:
        print(a, end=',')
        a, b = b, a+b
        fb_list.append(a)
        
        
fibo()
# Out:
# Please enter the number of finonacci numbers desired: -1
# Enter positive integer: 7
# 0,1,1,2,3,5,8,13,

# %%
#Question 3
import numpy as np

crt = np.random.rand(20,3)#cartesian coordinates

#compute magnitude, r, theta, phi
crt_sq = crt**2
r = np.sqrt(crt_sq.sum(axis=1)) #Magnitude array 
theta = np.arccos(crt[:,2]/r)   #theta, x-y plane angle
phi = np.arctan(crt[:,1]/crt[:,0]) #phi y-z plane

sph = np.zeros((20,3)) #an array to hold spherical cordinates
sph[:,0] = r
sph[:,1] = theta
sph[:,2] = phi
print('cartesian coordinates : \n',crt)
print('\n')
print('spherical coordinates : \n',sph)
# Out:
# cartesian coordinates :
#  [[0.25280275 0.21853759 0.54251876]
#  [0.69709059 0.31221234 0.39911348]
#  [0.07786226 0.99706075 0.91002235]
#  [0.05858134 0.99730918 0.89802355]
#  [0.44876152 0.55852544 0.25558631]
#  [0.61961676 0.48641322 0.68720393]
#  [0.66867432 0.46155795 0.2231627 ]
#  [0.35032583 0.40829671 0.37859047]
#  [0.78927736 0.10258234 0.50497474]
#  [0.51116892 0.25081931 0.17675392]
#  [0.72663015 0.62670731 0.78579006]
#  [0.13004283 0.35113304 0.25095078]
#  [0.9910089  0.40904233 0.47964108]
#  [0.23340621 0.98164014 0.96459403]
#  [0.38307872 0.9660254  0.20513905]
#  [0.35368031 0.6259325  0.87896221]
#  [0.62807116 0.31655628 0.25274419]
#  [0.68557674 0.66356167 0.32698565]
#  [0.19834003 0.20330882 0.18197883]
#  [0.98694503 0.01317883 0.68589486]]
#
#
# spherical coordinates :
#  [[0.63717699 0.55206905 0.71282853]
#  [0.86180242 1.08928991 0.42108882]
#  [1.35215878 0.83251948 1.4928627 ]
#  [1.34331815 0.8385909  1.51212435]
#  [0.76069832 1.22814118 0.89393976]
#  [1.04535735 0.85345092 0.66554149]
#  [0.84259283 1.30274552 0.60415789]
#  [0.65784887 0.9575838  0.86166592]
#  [0.9425929  1.00542498 0.12924545]
#  [0.59619287 1.26980088 0.45616219]
#  [1.24024975 0.88463227 0.71169751]
#  [0.45075697 0.98034993 1.21610681]
#  [1.17450834 1.15012203 0.39145214]
#  [1.39590023 0.80789806 1.33735939]
#  [1.0592622  1.37590267 1.19326641]
#  [1.13554208 0.68558887 1.05647534]
#  [0.74736931 1.2258157  0.46685317]
#  [1.00858771 1.24062882 0.76908174]
#  [0.33732705 1.00098525 0.79776853]
#  [1.20195089 0.96349755 0.01335236]]

# %%
import matplotlib.pyplot as plt

x_val = np.arange(0,10,0.001) #variable to hold 10/0.001 values of x b/n 0 & 10
f_x = np.exp(-x_val/10)*np.sin(np.pi*x_val) #f(x)
g_x = x_val*np.exp(-x_val/3)
plt.plot(x_val,f_x)
plt.plot(x_val,g_x)
plt.xlabel('x-axis (x)')
plt.ylabel('y-axis: f(x) or g(x)')
plt.legend(['f(x) = $e^{-x/10}sin(\pi x)$','g(x) = $xe^{-x/3}$'], loc='upper right')
plt.show()
